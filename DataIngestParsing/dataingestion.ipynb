# %%
import os
from typing import List,Dict,Any
import pandas as pd

# %%
from langchain_core.documents import Document
from langchain_text_splitters import (
    RecursiveCharacterTextSplitter,
    TextSplitter,
    TokenTextSplitter
)
print("setup done")
# Out:
# setup done

# %%
doc = Document(
    page_content="The main content will be here" ,
    metadata = {
        "source" : "file.txt" ,
        "page" : 1 ,
        "author" : "Yash"
    }
)

print("Document Structure")

print(f"Content : {doc.page_content}")
print(f"Metadata : {doc.metadata}")
# Out:
# Document Structure
# Content : The main content will be here
# Metadata : {'source': 'file.txt', 'page': 1, 'author': 'Yash'}
